# %% [markdown]
# ## Q2: Tossing a brick on ice (40 pts)

# %%
using Pkg;
const root = dirname(@__DIR__)
Pkg.activate(root);
Pkg.instantiate()
# Out:
#   Activating environment at `~/devel/dynamics-simulation-16-715/HW3_solutions/Project.toml`

# %%
using LinearAlgebra
using ForwardDiff
using Plots
using OrdinaryDiffEq
using Ipopt
using MathOptInterface
const MOI = MathOptInterface
using Test
const FD = ForwardDiff
using JLD2, FileIO
const jld2path = joinpath(root,"test");
include(joinpath(jld2path,"test_functions.jl"));

# %%
#Brick Parameters
const g = 9.81
const m = 1
const ℓ = 1
const J = Diagonal([0.5; 1; 1.5])
# Out:
# 3×3 Diagonal{Float64, Vector{Float64}}:
#  0.5   ⋅    ⋅
#   ⋅   1.0   ⋅
#   ⋅    ⋅   1.5

# %%
#Some standard functions for dealing with rotation matrices and quaternions from the class notes
#These can be given

function hat(ω)
    return [0 -ω[3] ω[2];
            ω[3] 0 -ω[1];
            -ω[2] ω[1] 0]
end

function L(Q)
    [Q[1] -Q[2:4]'; Q[2:4] Q[1]*I + hat(Q[2:4])]
end

function R(Q)
    [Q[1] -Q[2:4]'; Q[2:4] Q[1]*I - hat(Q[2:4])]
end

const H = [zeros(1,3); I];

const T = Diagonal([1.0; -1; -1; -1])

function G(Q)
    return L(Q)*H
end

function Ḡ(q)
    Q = q[4:7]
    return [I zeros(3,3); zeros(4,3) G(Q)]
end
function ρ(ϕ)
    # convert from ϕ to a quaternion
    return (1/sqrt(1 + dot(ϕ,ϕ)))*[1;ϕ]
end
# Out:
# WARNING: redefinition of constant H. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant T. This may fail, cause incorrect answers, or produce other errors.
# ρ (generic function with 1 method)

# %% [markdown]
# ## 2A: Newton-Euler dynamics (10 pts)

# %%
#Simulation Parameters
const h = 0.05 #20 Hz
const Tf = 5.0 #final time (sec)
const Thist = Array(0:h:Tf)
const N = length(Thist);
# Out:
# WARNING: redefinition of constant Thist. This may fail, cause incorrect answers, or produce other errors.

# %%
#Initial Conditions
const r0 = [0; 0; 3.0]
const v0 = [1.0; 0; 0.0]
const ϕ0 = 0.2*randn(3)
const Q0 = [sqrt(1.0-ϕ0'*ϕ0); ϕ0] #Random initial attitude
const ω0 = [1e-2*randn(); 4; 1e-2*randn()] #spin about the unstable intermediate axis of inertia
const x0 = [r0; Q0; v0; ω0];
# Out:
# WARNING: redefinition of constant r0. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant v0. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant ϕ0. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant Q0. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant ω0. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant x0. This may fail, cause incorrect answers, or produce other errors.

# %%
#Reference Solution

function f(x,p,t)
    # don't worry about p and t, they are irrelevant 
    
    #Unpack state vector
    r = x[1:3]   # position in world frame 
    Q = x[4:7]   # ^N Q ^B (quaternion)
    v = x[8:10]  # velocity in world frame
    ω = x[11:13] # ^N ω ^B (angular velocity)
    
    #Implement Newton-Euler dynamics
    ẋ = zeros(eltype(x),length(x))
    ###Solution:
    
    #Kinematics
    ṙ = v
    Q̇ = 0.5*L(Q)*H*ω
    
    #Dynamics
    v̇ = [0; 0; -g]
    ω̇ = J\(-hat(ω)*J*ω)
    
    ẋ .= [ṙ; Q̇; v̇; ω̇]
    
    return ẋ
end

# %%
@testset "dynamics" begin 
    r = [1;2;4.3]
    Q = normalize([.1;.3;-.2;.3])
    v = [-1;.3;4]
    ω = [.2;.3;-.1]
    x = [r;Q;v;ω]
    ẋ1 = f(x,0,0)
    test_vec(ẋ1,[-1.0, 0.3, 4.0, 0.03127716210856121, -0.05212860351426868, 0.12510864843424485, 0.12510864843424485, 0.0, 0.0, -9.81, 0.03, -0.020000000000000004, -0.02] )
end
# Out:
# Test Summary: | Pass  Total
# dynamics      |   13     13
# Test.DefaultTestSet("dynamics", Any[Test.DefaultTestSet("element #1", Any[], 1, false, false), Test.DefaultTestSet("element #2", Any[], 1, false, false), Test.DefaultTestSet("element #3", Any[], 1, false, false), Test.DefaultTestSet("element #4", Any[], 1, false, false), Test.DefaultTestSet("element #5", Any[], 1, false, false), Test.DefaultTestSet("element #6", Any[], 1, false, false), Test.DefaultTestSet("element #7", Any[], 1, false, false), Test.DefaultTestSet("element #8", Any[], 1, false, false), Test.DefaultTestSet("element #9", Any[], 1, false, false), Test.DefaultTestSet("element #10", Any[], 1, false, false), Test.DefaultTestSet("element #11", Any[], 1, false, false), Test.DefaultTestSet("element #12", Any[], 1, false, false), Test.DefaultTestSet("element #13", Any[], 1, false, false)], 0, false, false)

# %%
tspan = (0.0,Tf)
prob = ODEProblem(f,x0,tspan)
sol = solve(prob,Tsit5(),reltol=1e-8,abstol=1e-8);

# %%
#You should see the object falling in the z-direction while maintaining constant velocity in the x-direction
plot(sol, vars=(0,1),label = "r_x")
plot!(sol, vars=(0,2),label = "r_y")
plot!(sol, vars=(0,3),label = "r_z")
xlabel!("time (s)")
ylabel!("m")
title!("position history")

# %%
#You should see a characteristic flipping of the rotation axis due to spinning about the unstable intermediate axis
plot(sol, vars=(0,11),label = "ωₓ")
plot!(sol, vars=(0,12),label = "ω_y")
plot!(sol, vars=(0,13),label = "ω_z")
xlabel!("time (s)")
ylabel!("rad/s")
title!("angular velocity history")

# %% [markdown]
# ## 2B:

# %%
function DLT1(q1,q2)
    r1 = q1[1:3]
    Q1 = q1[4:7]
    r2 = q2[1:3]
    Q2 = q2[4:7]
    
    #Implement the right discrete Legendre transform for a free rigid body
    
    ###Solution
    [-(1/h)*m*(r2-r1) + (h/2)*m*[0; 0; -g]; #+ (h/2)*F;
    (2.0/h)*G(Q1)'*T*R(Q2)'*H*J*H'*L(Q1)'*Q2]; #+ (h/2)*τ];
end
# Out:
# DLT1 (generic function with 1 method)

# %%
@testset "DLT1" begin 
    r1 = [1;2;4.3]
    Q1 = normalize([.1;.3;-.2;.3])
    q1 = [r1;Q1]
    r2 = [1.3;-2;4.6]
    Q2 = normalize([.14;.2;-.1;.4])
    q2 = [r2;Q2]   
    D1 = DLT1(q1,q2)
    test_vec(D1, [-6.000000000000001, 80.0, -6.245249999999997, -1.9148613846386908, -12.898045750643837, 2.090592334494776])
end
# Out:
# Test Summary: | Pass  Total
# DLT1          |    6      6
# Test.DefaultTestSet("DLT1", Any[Test.DefaultTestSet("element #1", Any[], 1, false, false), Test.DefaultTestSet("element #2", Any[], 1, false, false), Test.DefaultTestSet("element #3", Any[], 1, false, false), Test.DefaultTestSet("element #4", Any[], 1, false, false), Test.DefaultTestSet("element #5", Any[], 1, false, false), Test.DefaultTestSet("element #6", Any[], 1, false, false)], 0, false, false)

# %%
function DLT2(q1,q2)
    r1 = q1[1:3]
    Q1 = q1[4:7]
    r2 = q2[1:3]
    Q2 = q2[4:7]
    
    #Implement the left discrete Legendre transform for a free rigid body
    
    #Solution
    [(1/h)*m*(r2-r1) + (h/2)*m*[0; 0; -g]; #+ (h/2)*F;
    (2.0/h)*G(Q2)'*L(Q1)*H*J*H'*L(Q1)'*Q2]; #+ (h/2)*τ];
end
# Out:
# DLT2 (generic function with 1 method)

# %%
@testset "DLT2" begin 
    r1 = [1;2;4.3]
    Q1 = normalize([.1;.3;-.2;.3])
    q1 = [r1;Q1]
    r2 = [1.3;-2;4.6]
    Q2 = normalize([.14;.2;-.1;.4])
    q2 = [r2;Q2]   
    D2 = DLT2(q1,q2)
    test_vec(D2, [6.000000000000001, -80.0, 5.754749999999996, 2.6238448719890917, 12.389031964853807, -3.744887138312375])
end
# Out:
# Test Summary: | Pass  Total
# DLT2          |    6      6
# Test.DefaultTestSet("DLT2", Any[Test.DefaultTestSet("element #1", Any[], 1, false, false), Test.DefaultTestSet("element #2", Any[], 1, false, false), Test.DefaultTestSet("element #3", Any[], 1, false, false), Test.DefaultTestSet("element #4", Any[], 1, false, false), Test.DefaultTestSet("element #5", Any[], 1, false, false), Test.DefaultTestSet("element #6", Any[], 1, false, false)], 0, false, false)

# %%
function DEL(q1,q2,q3)   
    #Implement the discrete Euler-Lagrange equation for a free rigid body
    
    ###Solution
    DLT2(q1,q2) + DLT1(q2,q3)
end
# Out:
# DEL (generic function with 1 method)

# %%
@testset "DLT2" begin 
    r1 = [1;2;4.3]
    Q1 = normalize([.1;.3;-.2;.3])
    q1 = [r1;Q1]
    r2 = [1.3;-2;4.6]
    Q2 = normalize([.14;.2;-.1;.4])
    q2 = [r2;Q2]   
    r3 = [2.3;-1;4.32]
    Q3 = normalize([.17;.23;-.112;.49])
    q3 = [r3;Q3] 
    D = DEL(q1,q2,q3)
    test_vec(D,[-13.999999999999996, -100.0, 11.109499999999983, 2.4506935890672716, 11.332809139030706, -3.749462832864676])
end
# Out:
# Test Summary: | Pass  Total
# DLT2          |    6      6
# Test.DefaultTestSet("DLT2", Any[Test.DefaultTestSet("element #1", Any[], 1, false, false), Test.DefaultTestSet("element #2", Any[], 1, false, false), Test.DefaultTestSet("element #3", Any[], 1, false, false), Test.DefaultTestSet("element #4", Any[], 1, false, false), Test.DefaultTestSet("element #5", Any[], 1, false, false), Test.DefaultTestSet("element #6", Any[], 1, false, false)], 0, false, false)

# %%
#First let's first simulate the rigid body with no contact using our midpoint variational integrator to make sure it looks reasonable

#Initial conditions (can provide this)
qhist = zeros(7,N)
qhist[:,1] .= [r0; Q0]
qhist[:,2] .= [r0 + h*v0; Q0 + h*0.5*L(Q0)*H*ω0]
qhist[4:7,2] .= qhist[4:7,2]/norm(qhist[4:7,2])

for k = 2:(N-1)
    qhist[:,k+1] .= qhist[:,k] #initial guess
    e = DEL(qhist[:,k-1], qhist[:,k], qhist[:,k+1]) #DEL residual
    
    while maximum(abs.(e)) > 1e-12
        
        # Implement Newton's method to solve for q_k+1. Remember to properly handle the quaternion.
        # this means that we will use the Ḡ function we defined earlier, such that the position is 
        # unaffected but the quaternion is handled appropriately. After you solve for the newton 
        # step, apply the step additively to the position, and apply the step multiplicatively to
        # the quaternion. 
        
        # hint: at each iteration we are solving for qhist[:,k+1] such that:
        # DEL(qhist[:,k-1], qhist[:,k], qhist[:,k+1]) = zeros()
        
        ###Solution
        De = FD.jacobian(dqn->DEL(qhist[:,k-1], qhist[:,k], dqn), qhist[:,k+1])*Ḡ(qhist[:,k+1])
        Δq = -De\e
        qhist[1:3,k+1] .= qhist[1:3,k+1] + Δq[1:3];
        qhist[4:7,k+1] .= L(qhist[4:7,k+1])*ρ(Δq[4:6]) 
        e = DEL(qhist[:,k-1], qhist[:,k], qhist[:,k+1])
        
        
    end
    
    # test the residual 
    @test norm(DEL(qhist[:,k-1], qhist[:,k], qhist[:,k+1])) < 1e-6
end

#Calculate midpoint velocity approximations for plotting
vhist = zeros(3,N-1)
ωhist = zeros(3,N-1)
for k = 1:(N-1)
    
    # Implement midpoint finite-difference approximation for translational + angular velocity
    # hint: you may assume that the quaternion ^B(k)Q^B(k+1) is [1;ωk*h/2] (where ^NQ^B(k) = qhist[4:7,k])
    ###Solution:
    vhist[:,k] .= (qhist[1:3,k+1]-qhist[1:3,k])/h
    ωhist[:,k] .= (2.0/h)*H'*L(qhist[4:7,k])'*qhist[4:7,k+1]
    
end

# %%
@testset "midpoint velocities" begin 
    for k = 1:(N-1)
        @test isapprox(qhist[1:3,k+1], qhist[1:3,k] + vhist[:,k]*h,rtol = 1e-9)
        @test isapprox( H'*L(qhist[4:7,k])'*qhist[4:7,k+1],ωhist[:,k]*h/2,rtol = 1e-9)
    end
end
# Out:
# Test Summary:       | Pass  Total
# midpoint velocities |  200    200
# Test.DefaultTestSet("midpoint velocities", Any[], 200, false, false)

# %%
#Compare with reference solution. You should see similar behavior
plot(Thist, qhist[1,:],label = "r_x")
plot!(Thist, qhist[2,:],label = "r_y")
plot!(Thist, qhist[3,:],label = "r_z")
plot!(sol, vars=(0,1),label = "true r_x",color = :red,linestyle = :dash)
plot!(sol, vars=(0,2),label = "true r_y",color = :red,linestyle = :dash)
plot!(sol, vars=(0,3),label = "true r_z",color = :red,linestyle = :dash)
xlabel!("time (s)")
ylabel!("m")
title!("position history")

# %%
@test norm(sol(Tf)[1:3] - qhist[1:3,end]) < 5
# Out:
# Test Passed

# %%
#Compare with reference solution. You should see similar behavior (spin axis flip)
plot(Thist[1:end-1],ωhist[1,:],label = "ωₓ")
plot!(Thist[1:end-1],ωhist[2,:],label = "ω_y")
plot!(Thist[1:end-1],ωhist[3,:],label = "ω_z")
plot!(sol, vars=(0,11),label = "true ω_x",color = :red,linestyle = :dash)
plot!(sol, vars=(0,12),label = "true ω_y",color = :red,linestyle = :dash)
plot!(sol, vars=(0,13),label = "true ω_z",color = :red,linestyle = :dash)
xlabel!("time (s)")
ylabel!("rad/s")
title!("angular velocity history")

# %%
@test norm(sol(Tf)[11:13] - ωhist[1:3,end]) < .5
@test norm(sol(Tf)[8:10] - vhist[1:3,end]) < 2
# Out:
# Test Passed

# %%
#Visualize the falling brick

using MeshCat
using CoordinateTransformations
using Rotations
using GeometryBasics: HyperRectangle, Vec, Point, Mesh
using Colors: RGBA, RGB

vis = Visualizer()
render(vis)
# Out:
# ┌ Info: MeshCat server started. You can open the visualizer by visiting the following URL in your browser:
# │ http://127.0.0.1:8704
# └ @ MeshCat /Users/kevintracy/.julia/packages/MeshCat/RLYij/src/visualizer.jl:73
# MeshCat.DisplayedVisualizer(MeshCat.CoreVisualizer(MeshCat.SceneTrees.SceneNode(nothing, nothing, Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}()), Set{Any}(), ip"127.0.0.1", 8704))

# %%
# you can use (ctrl + enter) to run this cell without shifting the window down 
delete!(vis)

# our box 
box = HyperRectangle(Vec(-0.5, -.5, -0.5), Vec(1, 1, 1))
setobject!(vis["box"],box)

for k = 1:N
    
    # set position and attitude
    attitude = LinearMap(UnitQuaternion(qhist[4:7,k]))
    position = Translation(qhist[1:3,k])
    settransform!(vis["box"], compose(position,attitude))
    sleep(h)
end

# %% [markdown]
# ## Contact dynamics through optimization
#
# We are going to setup and solve the following.
# $$ \begin{align}
# \min_{q_{k+1},\lambda_k,s_k} && \sum_{i=1}^8s_{k,i} \\
# \text{st} && DEL(q_{k-1},q_k,q_{k+1}) &= 0 \\
#  && \|q_{k+1}\|^2 - 1 &= 0 && \text{unit norm constraint}\\
#  && d(q_{k+1}) &\geq 0 && \text{corners must stay above ground}\\
#  && s_k - \text{diag}(\lambda_k)d(q_{k+1}) &\geq 0 && \text{collision constraint}\\
#  && \lambda_k &\geq 0 \\
#  && s_k &\geq 0
# \end{align} $$

# %%
#Boilerplate setup code to interface with IPOPT. Don't touch this except to turn on/off verbose IPOPT if you want (see comment below).

struct ProblemMOI <: MOI.AbstractNLPEvaluator
    n_nlp::Int
    m_nlp::Int
    idx_ineq
    obj_grad::Bool
    con_jac::Bool
    sparsity_jac
    sparsity_hess
    primal_bounds
    constraint_bounds
    hessian_lagrangian::Bool
end

function ProblemMOI(n_nlp,m_nlp;
        idx_ineq=(1:0),
        obj_grad=true,
        con_jac=true,
        sparsity_jac=sparsity_jacobian(n_nlp,m_nlp),
        sparsity_hess=sparsity_hessian(n_nlp,m_nlp),
        primal_bounds=primal_bounds(n_nlp),
        constraint_bounds=constraint_bounds(m_nlp,idx_ineq=idx_ineq),
        hessian_lagrangian=false)

    ProblemMOI(n_nlp,m_nlp,
        idx_ineq,
        obj_grad,
        con_jac,
        sparsity_jac,
        sparsity_hess,
        primal_bounds,
        constraint_bounds,
        hessian_lagrangian)
end

function constraint_bounds(m; idx_ineq=(1:0))
    c_l = zeros(m)

    c_u = zeros(m)
    c_u[idx_ineq] .= Inf
    
    return c_l, c_u
end

function row_col!(row,col,r,c)
    for cc in c
        for rr in r
            push!(row,convert(Int,rr))
            push!(col,convert(Int,cc))
        end
    end
    return row, col
end

function sparsity_jacobian(n,m)

    row = []
    col = []

    r = 1:m
    c = 1:n

    row_col!(row,col,r,c)

    return collect(zip(row,col))
end

function sparsity_hessian(n,m)

    row = []
    col = []

    r = 1:m
    c = 1:n

    row_col!(row,col,r,c)

    return collect(zip(row,col))
end

function MOI.eval_objective(prob::MOI.AbstractNLPEvaluator, x)
    objective(x)
end

function MOI.eval_objective_gradient(prob::MOI.AbstractNLPEvaluator, grad_f, x)
    ForwardDiff.gradient!(grad_f,objective,x)
    return nothing
end

function MOI.eval_constraint(prob::MOI.AbstractNLPEvaluator,g,x)
    constraint!(g,x)
    return nothing
end

function MOI.eval_constraint_jacobian(prob::MOI.AbstractNLPEvaluator, jac, x)
    ForwardDiff.jacobian!(reshape(jac,prob.m_nlp,prob.n_nlp), constraint!, zeros(prob.m_nlp), x)
    return nothing
end

function MOI.features_available(prob::MOI.AbstractNLPEvaluator)
    return [:Grad, :Jac]
end

MOI.initialize(prob::MOI.AbstractNLPEvaluator, features) = nothing
MOI.jacobian_structure(prob::MOI.AbstractNLPEvaluator) = prob.sparsity_jac

function ipopt_solve(x0,prob::MOI.AbstractNLPEvaluator;
        tol=1.0e-9,c_tol=1.0e-9,max_iter=10000)
    x_l, x_u = prob.primal_bounds
    c_l, c_u = prob.constraint_bounds

    nlp_bounds = MOI.NLPBoundsPair.(c_l,c_u)
    block_data = MOI.NLPBlockData(nlp_bounds,prob,true)

    solver = Ipopt.Optimizer()
    solver.options["max_iter"] = max_iter
    solver.options["tol"] = tol
    solver.options["constr_viol_tol"] = c_tol
    
    #Uncomment the following line to turn off verbose IPOPT output
    #solver.options["print_level"] = 0

    x = MOI.add_variables(solver,prob.n_nlp)

    for i = 1:prob.n_nlp
        xi = MOI.SingleVariable(x[i])
        MOI.add_constraint(solver, xi, MOI.LessThan(x_u[i]))
        MOI.add_constraint(solver, xi, MOI.GreaterThan(x_l[i]))
        MOI.set(solver, MOI.VariablePrimalStart(), x[i], x0[i])
    end

    # Solve the problem
    MOI.set(solver, MOI.NLPBlock(), block_data)
    MOI.set(solver, MOI.ObjectiveSense(), MOI.MIN_SENSE)
    MOI.optimize!(solver)

    # Get the solution
    res = MOI.get(solver, MOI.VariablePrimal(), x)

    return res
end
# Out:
# ipopt_solve (generic function with 1 method)

# %%
function d(q)
    #Calculate the height (z coordinate) of the 8 corners of the brick in the world frame.
    #Assume it is a cube with sides of length ℓ
    #Output should be an 8×1 vector
    
    r = q[1:3] #position
    Q = q[4:7] #quaternion
    
    ###Solution:
    S = H'R(Q)'*L(Q)H #Rotation matrix
    Sz = S[3,:] #Last row of rotation matrix from B to N gives z component in N frame
    
    ϕ = [r[3] + 0.5*Sz'*[ℓ; ℓ; ℓ];
         r[3] + 0.5*Sz'*[ℓ; -ℓ; ℓ];
         r[3] + 0.5*Sz'*[-ℓ; -ℓ; ℓ];
         r[3] + 0.5*Sz'*[-ℓ; ℓ; ℓ];
         r[3] + 0.5*Sz'*[ℓ; ℓ; -ℓ];
         r[3] + 0.5*Sz'*[ℓ; -ℓ; -ℓ];
         r[3] + 0.5*Sz'*[-ℓ; -ℓ; -ℓ];
         r[3] + 0.5*Sz'*[-ℓ; ℓ; -ℓ]]
end

function Dd(q)
    #Implement the kinematic Jacobian corresponding to d(q) above. Output should be a 8×6 matrix
    
    ###Solution:
    FD.jacobian(dq->d(dq),q)*Ḡ(q)
end
# Out:
# Dd (generic function with 1 method)

# %%
@testset "height and kinematic jacobian" begin 
    r = [1;-2;3.21]
    Q = normalize([1;.2;.8;-.4])
    q = [r;Q]
    
    d1=d(q)
    Dd1 = Dd(q)
    
    test_vec(d1, [2.796956521739131, 2.927391304347826, 3.8839130434782607, 3.753478260869565, 2.536086956521739, 2.666521739130435, 3.623043478260869, 3.492608695652174])
    @test size(Dd1) == (8,6)
    test_vec(vec(Dd1),vec([0.0 0.0 1.0 0.39130434782608675 -1.2173913043478255 0.8260869565217388; 0.0 0.0 1.0 -0.13043478260869557 -1.2173913043478257 -1.0869565217391302; 0.0 0.0 1.0 -0.13043478260869565 -0.6956521739130433 -0.8260869565217388; 0.0 0.0 1.0 0.39130434782608675 -0.6956521739130431 1.08695652173913; 0.0 0.0 1.0 0.13043478260869565 0.6956521739130433 0.8260869565217388; 0.0 0.0 1.0 -0.39130434782608675 0.6956521739130431 -1.08695652173913; 0.0 0.0 1.0 -0.39130434782608675 1.2173913043478255 -0.8260869565217388; 0.0 0.0 1.0 0.13043478260869557 1.2173913043478257 1.0869565217391302]))
end
# Out:
# Test Summary:                 | Pass  Total
# height and kinematic jacobian |   57     57
# Test.DefaultTestSet("height and kinematic jacobian", Any[Test.DefaultTestSet("element #1", Any[], 1, false, false), Test.DefaultTestSet("element #2", Any[], 1, false, false), Test.DefaultTestSet("element #3", Any[], 1, false, false), Test.DefaultTestSet("element #4", Any[], 1, false, false), Test.DefaultTestSet("element #5", Any[], 1, false, false), Test.DefaultTestSet("element #6", Any[], 1, false, false), Test.DefaultTestSet("element #7", Any[], 1, false, false), Test.DefaultTestSet("element #8", Any[], 1, false, false), Test.DefaultTestSet("element #1", Any[], 1, false, false), Test.DefaultTestSet("element #2", Any[], 1, false, false)  …  Test.DefaultTestSet("element #39", Any[], 1, false, false), Test.DefaultTestSet("element #40", Any[], 1, false, false), Test.DefaultTestSet("element #41", Any[], 1, false, false), Test.DefaultTestSet("element #42", Any[], 1, false, false), Test.DefaultTestSet("element #43", Any[], 1, false, false), Test.DefaultTestSet("element #44", Any[], 1, false, false), Test.DefaultTestSet("element #45", Any[], 1, false, false), Test.DefaultTestSet("element #46", Any[], 1, false, false), Test.DefaultTestSet("element #47", Any[], 1, false, false), Test.DefaultTestSet("element #48", Any[], 1, false, false)], 1, false, false)

# %%
function DEL(q1,q2,q3,λ)    
    #Implement the constrained discrete Euler-Lagrange equation that accounts for the collision constraints and corresponding normal forces λ
    
    ###Solution:
    DLT2(q1,q2) + DLT1(q2,q3) + h*Dd(q2)'*λ
end
# Out:
# DEL (generic function with 2 methods)

# %%
#Objective and constraint functions for IPOPT

function objective(z)
    qn = z[1:7]
    λ = z[8:15]
    s = z[16:23]
    
    #Let's provide this
    return sum(s) #Minimize slacks associated with complementarity conditions
end

function constraint!(c,z)
    qn = z[1:7]
    λ = z[8:15]
    s = z[16:23]
    
    #Implement the nonlinear DEL, quaternion, and collision constraints

    ###Solution
    c .= [DEL(qhist[:,k-1],qhist[:,k],qn,λ); #6
          qn[4:7]'*qn[4:7]-1.0 #1
          d(qn); #8
          s-Diagonal(λ)*d(qn)] #8
    
    return nothing
end

#Specify the indicies of c (constraint output) that should be non-negative.
#The rest will be treated as equality constraints.
#This can vary depending on how you stacked up c above.
###Solution:
nonnegative_constraint_indices = (8:23)

function primal_bounds(n)
    #Enforce simple bound constraints on the decision variables (e.g. positivity) here
    
    ###Solution
    x_l = -Inf*ones(n)
    x_u = Inf*ones(n)
    
    x_l[8:23] .= zeros(16)
    
    return x_l, x_u
end
# Out:
# primal_bounds (generic function with 1 method)

# %%
#Solve with IPOPT
n_nlp = 23
m_nlp = 23
nlp_prob = ProblemMOI(n_nlp,m_nlp, idx_ineq=nonnegative_constraint_indices);

#Initial conditions
qhist = zeros(7,N)
qhist[:,1] .= [r0; Q0]
qhist[:,2] .= [r0 + h*v0; Q0 + h*0.5*L(Q0)*H*ω0]
qhist[4:7,2] .= qhist[4:7,2]/norm(qhist[4:7,2])

λhist = zeros(8,N)
shist = zeros(8,N)
k = 0

for kk = 2:(N-1)
    k = kk
    z_guess = [qhist[:,k]; zeros(8); ones(8)]
    z_sol = ipopt_solve(z_guess,nlp_prob);
    qhist[:,k+1] .= z_sol[1:7]
    λhist[:,k] .= z_sol[8:15]
    shist[:,k] .= z_sol[16:23]
end
# Out:
# This is Ipopt version 3.13.4, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      161
# Number of nonzeros in inequality constraint Jacobian.:      368
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Total number of variables............................:       23
#                      variables with only lower bounds:       16
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        7
# Total number of inequality constraints...............:       16
#         inequality constraints with only lower bounds:       16
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  8.0000000e+00 3.96e+00 7.03e-01   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.4094718e+00 9.80e-03 3.02e-01  -2.0 3.27e-01    -  9.64e-01 1.00e+00f  1
#    2  1.5422796e+00 9.67e-05 4.82e-01  -6.8 4.84e-01    -  9.85e-01 1.00e+00f  1
#    3  2.4136247e-02 2.87e-05 3.03e-01  -3.7 2.71e-01    -  1.00e+00 7.03e-01f  1
#    4  3.4226093e-04 7.86e-06 1.72e-01  -5.3 4.72e-03    -  1.00e+00 7.26e-01f  1
#    5  4.2569227e-06 8.21e-08 2.25e-07  -7.0 4.51e-05    -  1.00e+00 9.90e-01h  1
#    6 -5.6024100e-08 2.60e-09 4.75e-10 -11.0 5.68e-07    -  1.00e+00 9.68e-01h  1
#    7 -7.8733893e-08 1.20e-09 3.43e-10 -11.0 1.08e-08    -  1.00e+00 5.40e-01h  1
#    8 -7.9783349e-08 1.60e-10 3.65e-11 -10.5 8.13e-10    -  1.00e+00 8.67e-01h  1
#
# Number of Iterations....: 8
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -7.9783348706779285e-08   -7.9783348706779285e-08
# Dual infeasibility......:   3.6510611808177051e-11    3.6510611808177051e-11
# Constraint violation....:   1.5972960497607315e-10    1.5972960497607315e-10
# Complementarity.........:   4.6099340908272593e-11    4.6099340908272593e-11
# Overall NLP error.......:   1.5972960497607315e-10    1.5972960497607315e-10
#
#
# Number of objective function evaluations             = 9
# Number of objective gradient evaluations             = 9
# Number of equality constraint evaluations            = 9
# Number of inequality constraint evaluations          = 9
# Number of equality constraint Jacobian evaluations   = 9
# Number of inequality constraint Jacobian evaluations = 9
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.438
# Total CPU secs in NLP function evaluations           =      0.050
#
# EXIT: Optimal Solution Found.
# This is Ipopt version 3.13.4, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      161
# Number of nonzeros in inequality constraint Jacobian.:      368
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Total number of variables............................:       23
#                      variables with only lower bounds:       16
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        7
# Total number of inequality constraints...............:       16
#         inequality constraints with only lower bounds:       16
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  8.0000000e+00 3.96e+00 7.04e-01   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.4086643e+00 9.80e-03 3.07e-01  -2.0 3.27e-01    -  9.71e-01 1.00e+00f  1
#    2  1.5183937e+00 9.67e-05 4.85e-01  -6.8 4.87e-01    -  9.85e-01 1.00e+00f  1
#    3  2.4112914e-02 2.93e-05 3.03e-01  -3.7 2.69e-01    -  1.00e+00 6.97e-01f  1
#    4  3.4116603e-04 7.96e-06 1.70e-01  -5.3 4.69e-03    -  1.00e+00 7.28e-01f  1
#    5  4.2348760e-06 8.28e-08 2.55e-07  -7.0 4.48e-05    -  1.00e+00 9.90e-01h  1
#    6 -5.5847848e-08 2.61e-09 7.41e-10 -11.0 5.64e-07    -  1.00e+00 9.69e-01h  1
#    7 -7.8573855e-08 1.20e-09 4.86e-10 -11.0 1.10e-08    -  1.00e+00 5.38e-01h  1
#    8 -7.9790466e-08 1.77e-10 4.88e-11 -10.6 9.21e-10    -  1.00e+00 8.53e-01h  1
#
# Number of Iterations....: 8
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -7.9790465966612236e-08   -7.9790465966612236e-08
# Dual infeasibility......:   4.8794871138416185e-11    4.8794871138416185e-11
# Constraint violation....:   1.7714319474689202e-10    1.7714319474689202e-10
# Complementarity.........:   4.4104218495292525e-11    4.4104218495292525e-11
# Overall NLP error.......:   1.7714319474689202e-10    1.7714319474689202e-10
#
#
# Number of objective function evaluations             = 9
# Number of objective gradient evaluations             = 9
# Number of equality constraint evaluations            = 9
# Number of inequality constraint evaluations          = 9
# Number of equality constraint Jacobian evaluations   = 9
# Number of inequality constraint Jacobian evaluations = 9
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.014
# Total CPU secs in NLP function evaluations           =      0.007
#
# EXIT: Optimal Solution Found.
# This is Ipopt version 3.13.4, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      161
# Number of nonzeros in inequality constraint Jacobian.:      368
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Total number of variables............................:       23
#                      variables with only lower bounds:       16
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        7
# Total number of inequality constraints...............:       16
#         inequality constraints with only lower bounds:       16
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  8.0000000e+00 3.96e+00 7.03e-01   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.4076453e+00 9.80e-03 3.12e-01  -2.0 3.28e-01    -  9.79e-01 1.00e+00f  1
#    2  1.4896417e+00 9.67e-05 4.89e-01  -6.8 4.90e-01    -  9.84e-01 1.00e+00f  1
#    3  2.3811343e-02 2.99e-05 3.02e-01  -3.7 2.67e-01    -  1.00e+00 6.90e-01f  1
#    4  3.3786417e-04 8.07e-06 1.66e-01  -5.3 4.59e-03    -  1.00e+00 7.30e-01f  1
#    5  4.1798988e-06 8.31e-08 2.81e-07  -7.0 4.42e-05    -  1.00e+00 9.90e-01h  1
#    6 -5.5896894e-08 2.60e-09 1.26e-09 -11.0 5.58e-07    -  1.00e+00 9.69e-01h  1
#    7 -7.8891296e-08 1.14e-09 6.84e-10 -10.2 1.09e-08    -  1.00e+00 5.60e-01h  1
#    8 -7.9776308e-08 1.65e-10 6.02e-11 -10.5 7.65e-10    -  1.00e+00 8.56e-01h  1
#
# Number of Iterations....: 8
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -7.9776307724149154e-08   -7.9776307724149154e-08
# Dual infeasibility......:   6.0160471222758805e-11    6.0160471222758805e-11
# Constraint violation....:   1.6472605794769866e-10    1.6472605794769866e-10
# Complementarity.........:   4.6209384965752359e-11    4.6209384965752359e-11
# Overall NLP error.......:   1.6472605794769866e-10    1.6472605794769866e-10
#
#
# Number of objective function evaluations             = 9
# Number of objective gradient evaluations             = 9
# Number of equality constraint evaluations            = 9
# Number of inequality constraint evaluations          = 9
# Number of equality constraint Jacobian evaluations   = 9
# Number of inequality constraint Jacobian evaluations = 9
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.014
# Total CPU secs in NLP function evaluations           =      0.007
#
# EXIT: Optimal Solution Found.
# This is Ipopt version 3.13.4, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      161
# Number of nonzeros in inequality constraint Jacobian.:      368
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Total number of variables............................:       23
#                      variables with only lower bounds:       16
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        7
# Total number of inequality constraints...............:       16
#         inequality constraints with only lower bounds:       16
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  8.0000000e+00 3.96e+00 6.97e-01   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.4063868e+00 9.80e-03 3.18e-01  -2.0 3.28e-01    -  9.88e-01 1.00e+00f  1
#    2  1.4550022e+00 9.67e-05 4.93e-01  -6.8 4.94e-01    -  9.84e-01 1.00e+00f  1
#    3  2.3195017e-02 3.08e-05 3.01e-01  -3.7 2.64e-01    -  1.00e+00 6.82e-01f  1
#    4  3.2850579e-04 8.20e-06 1.60e-01  -5.3 4.42e-03    -  1.00e+00 7.33e-01f  1
#    5  4.0380837e-06 8.29e-08 3.11e-07  -7.0 4.29e-05    -  1.00e+00 9.90e-01h  1
#    6 -5.6323351e-08 2.59e-09 2.17e-09 -11.0 5.39e-07    -  1.00e+00 9.69e-01h  1
#    7 -7.8782351e-08 1.16e-09 9.70e-10 -10.4 1.08e-08    -  1.00e+00 5.54e-01h  1
#    8 -7.9785029e-08 1.73e-10 1.14e-10 -10.5 8.19e-10    -  1.00e+00 8.50e-01h  1
#
# Number of Iterations....: 8
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -7.9785029219994026e-08   -7.9785029219994026e-08
# Dual infeasibility......:   1.1428376994748746e-10    1.1428376994748746e-10
# Constraint violation....:   1.7312788541353637e-10    1.7312788541353637e-10
# Complementarity.........:   4.4061153350564902e-11    4.4061153350564902e-11
# Overall NLP error.......:   1.7312788541353637e-10    1.7312788541353637e-10
#
#
# Number of objective function evaluations             = 9
# Number of objective gradient evaluations             = 9
# Number of equality constraint evaluations            = 9
# Number of inequality constraint evaluations          = 9
# Number of equality constraint Jacobian evaluations   = 9
# Number of inequality constraint Jacobian evaluations = 9
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.015
# Total CPU secs in NLP function evaluations           =      0.007
#
# EXIT: Optimal Solution Found.
# This is Ipopt version 3.13.4, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      161
# Number of nonzeros in inequality constraint Jacobian.:      368
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Total number of variables............................:       23
#                      variables with only lower bounds:       16
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        7
# Total number of inequality constraints...............:       16
#         inequality constraints with only lower bounds:       16
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  8.0000000e+00 3.96e+00 6.88e-01   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.4048482e+00 9.80e-03 3.24e-01  -2.0 3.28e-01    -  9.97e-01 1.00e+00h  1
#    2  1.4187891e+00 9.67e-05 4.97e-01  -6.8 4.98e-01    -  9.84e-01 1.00e+00f  1
#    3  2.2322184e-02 3.16e-05 3.00e-01  -3.7 2.61e-01    -  1.00e+00 6.73e-01f  1
#    4  3.1381027e-04 8.33e-06 1.52e-01  -5.3 4.19e-03    -  1.00e+00 7.36e-01f  1
#    5  3.8684155e-06 8.31e-08 3.35e-07  -7.1 4.09e-05    -  1.00e+00 9.90e-01h  1
#    6 -5.7069427e-08 2.60e-09 3.22e-09 -11.0 5.18e-07    -  1.00e+00 9.69e-01h  1
#    7 -7.8736003e-08 1.15e-09 1.43e-09 -10.4 1.04e-08    -  1.00e+00 5.56e-01h  1
#    8 -7.9796973e-08 1.73e-10 2.13e-10 -10.5 7.81e-10    -  1.00e+00 8.50e-01h  1
#
# Number of Iterations....: 8
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -7.9796973222508916e-08   -7.9796973222508916e-08
# Dual infeasibility......:   2.1336554051343271e-10    2.1336554051343271e-10
# Constraint violation....:   1.7322994767968922e-10    1.7322994767968922e-10
# Complementarity.........:   4.1097701749207838e-11    4.1097701749207838e-11
# Overall NLP error.......:   2.1336554051343271e-10    2.1336554051343271e-10
#
#
# Number of objective function evaluations             = 9
# Number of objective gradient evaluations             = 9
# Number of equality constraint evaluations            = 9
# Number of inequality constraint evaluations          = 9
# Number of equality constraint Jacobian evaluations   = 9
# Number of inequality constraint Jacobian evaluations = 9
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.015
# Total CPU secs in NLP function evaluations           =      0.007
#
# EXIT: Optimal Solution Found.
# This is Ipopt version 3.13.4, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      161
# Number of nonzeros in inequality constraint Jacobian.:      368
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Total number of variables............................:       23
#                      variables with only lower bounds:       16
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        7
# Total number of inequality constraints...............:       16
#         inequality constraints with only lower bounds:       16
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  8.0000000e+00 3.96e+00 6.74e-01   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.4029752e+00 9.80e-03 3.27e-01  -2.0 3.28e-01    -  1.00e+00 1.00e+00h  1
#    2  1.4054427e+00 9.66e-05 4.99e-01  -6.8 5.00e-01    -  9.84e-01 1.00e+00f  1
#    3  2.1560318e-02 3.19e-05 3.00e-01  -3.7 2.59e-01    -  1.00e+00 6.70e-01f  1
#    4  2.9817699e-04 8.36e-06 1.42e-01  -5.4 3.99e-03    -  1.00e+00 7.38e-01f  1
#    5  3.6902261e-06 8.27e-08 3.46e-07  -7.1 3.87e-05    -  1.00e+00 9.90e-01h  1
#    6 -5.7532764e-08 2.57e-09 3.91e-09 -11.0 4.96e-07    -  1.00e+00 9.69e-01h  1
#    7 -7.8447158e-08 1.17e-09 2.18e-09 -11.0 9.98e-09    -  1.00e+00 5.45e-01h  1
#    8 -7.9819531e-08 1.77e-10 4.78e-10 -10.5 8.27e-10    -  1.00e+00 8.49e-01h  1
#
# Number of Iterations....: 8
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -7.9819531230821536e-08   -7.9819531230821536e-08
# Dual infeasibility......:   4.7823726055662430e-10    4.7823726055662430e-10
# Constraint violation....:   1.7728462284759799e-10    1.7728462284759799e-10
# Complementarity.........:   5.6306200468431316e-11    5.6306200468431316e-11
# Overall NLP error.......:   4.7823726055662430e-10    4.7823726055662430e-10
#
#
# Number of objective function evaluations             = 9
# Number of objective gradient evaluations             = 9
# Number of equality constraint evaluations            = 9
# Number of inequality constraint evaluations          = 9
# Number of equality constraint Jacobian evaluations   = 9
# Number of inequality constraint Jacobian evaluations = 9
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.015
# Total CPU secs in NLP function evaluations           =      0.008
#
# EXIT: Optimal Solution Found.
# This is Ipopt version 3.13.4, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      161
# Number of nonzeros in inequality constraint Jacobian.:      368
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Total number of variables............................:       23
#                      variables with only lower bounds:       16
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        7
# Total number of inequality constraints...............:       16
#         inequality constraints with only lower bounds:       16
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  8.0000000e+00 3.96e+00 6.54e-01   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.3463107e+00 7.42e-02 3.41e-01  -6.0 3.42e-01    -  1.00e+00 9.81e-01h  1
#    2  9.6869637e-02 2.59e-02 1.71e-01  -2.9 1.01e+00    -  9.94e-01 6.54e-01f  1
#    3  1.6504023e-03 2.58e-04 8.62e-03  -4.3 1.52e-02    -  1.00e+00 9.92e-01h  1
#    4  2.4418349e-05 1.04e-06 5.73e-05  -6.1 2.21e-04    -  1.00e+00 9.96e-01h  1
#    5 -5.2800436e-08 4.96e-09 2.68e-08 -11.0 3.23e-06    -  1.00e+00 9.95e-01h  1
#    6 -7.8320729e-08 2.04e-09 4.56e-11 -10.0 1.03e-08    -  1.00e+00 5.89e-01h  1
#    7 -7.9659631e-08 3.18e-10 1.16e-11 -10.3 9.06e-10    -  1.00e+00 8.44e-01h  1
#
# Number of Iterations....: 7
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -7.9659630524376784e-08   -7.9659630524376784e-08
# Dual infeasibility......:   1.1566414492847343e-11    1.1566414492847343e-11
# Constraint violation....:   3.1767961663226622e-10    3.1767961663226622e-10
# Complementarity.........:   1.7104247674298742e-10    1.7104247674298742e-10
# Overall NLP error.......:   3.1767961663226622e-10    3.1767961663226622e-10
#
#
# Number of objective function evaluations             = 8
# Number of objective gradient evaluations             = 8
# Number of equality constraint evaluations            = 8
# Number of inequality constraint evaluations          = 8
# Number of equality constraint Jacobian evaluations   = 8
# Number of inequality constraint Jacobian evaluations = 8
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.016
# Total CPU secs in NLP function evaluations           =      0.007
#
# EXIT: Optimal Solution Found.
# This is Ipopt version 3.13.4, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      161
# Number of nonzeros in inequality constraint Jacobian.:      368
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Total number of variables............................:       23
#                      variables with only lower bounds:       16
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        7
# Total number of inequality constraints...............:       16
#         inequality constraints with only lower bounds:       16
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  8.0000000e+00 3.96e+00 6.36e-01   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.3004087e+00 9.80e-03 3.40e-01  -6.0 3.40e-01    -  1.00e+00 1.00e+00h  1
#    2  9.3003335e-02 3.40e-03 1.58e-01  -2.9 9.99e-01    -  9.89e-01 6.55e-01f  1
#    3  1.5832302e-03 3.34e-05 1.28e-02  -4.3 1.43e-02    -  1.00e+00 9.91e-01h  1
#    4  2.9892336e-05 4.55e-08 2.18e-04  -5.9 2.09e-04    -  1.00e+00 9.99e-01h  1
#    5  7.9666878e-08 4.89e-15 3.77e-06  -8.0 3.98e-06    -  1.00e+00 1.00e+00h  1
#    6 -6.6006729e-08 3.93e-15 6.13e-11 -11.0 2.89e-08    -  1.00e+00 6.85e-01h  1
#    7 -7.9799231e-08 1.43e-15 6.55e-12 -11.0 5.64e-09    -  1.00e+00 6.92e-01h  1
#
# Number of Iterations....: 7
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -7.9799230862844934e-08   -7.9799230862844934e-08
# Dual infeasibility......:   6.5469296650633169e-12    6.5469296650633169e-12
# Constraint violation....:   1.4313399222460433e-15    1.4313399222460433e-15
# Complementarity.........:   8.8769333206794451e-10    8.8769333206794451e-10
# Overall NLP error.......:   8.8769333206794451e-10    8.8769333206794451e-10
#
#
# Number of objective function evaluations             = 8
# Number of objective gradient evaluations             = 8
# Number of equality constraint evaluations            = 8
# Number of inequality constraint evaluations          = 8
# Number of equality constraint Jacobian evaluations   = 8
# Number of inequality constraint Jacobian evaluations = 8
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.013
# Total CPU secs in NLP function evaluations           =      0.006
#
# EXIT: Optimal Solution Found.
# This is Ipopt version 3.13.4, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      161
# Number of nonzeros in inequality constraint Jacobian.:      368
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Total number of variables............................:       23
#                      variables with only lower bounds:       16
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        7
# Total number of inequality constraints...............:       16
#         inequality constraints with only lower bounds:       16
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  8.0000000e+00 4.41e+00 6.27e-01   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.3054094e+00 9.80e-03 3.40e-01  -6.0 3.40e-01    -  1.00e+00 1.00e+00h  1
#    2  9.4451697e-02 3.39e-03 1.40e-01  -2.9 9.97e-01    -  9.86e-01 6.55e-01f  1
#    3  1.5792086e-03 3.41e-05 2.21e-02  -4.3 1.42e-02    -  1.00e+00 9.91e-01h  1
#    4  4.1842760e-05 2.05e-07 6.53e-04  -5.8 2.05e-04    -  1.00e+00 9.94e-01h  1
#    5  1.7498768e-07 3.98e-14 5.21e-06  -7.9 5.66e-06    -  1.00e+00 1.00e+00h  1
#    6 -6.0739548e-08 1.19e-14 1.21e-10 -11.0 4.06e-08    -  1.00e+00 7.56e-01h  1
#    7 -7.9414570e-08 2.25e-15 1.31e-10 -11.0 7.46e-09    -  1.00e+00 6.58e-01h  1
#    8 -7.9921636e-08 3.05e-15 1.37e-12 -11.0 4.82e-10    -  1.00e+00 8.23e-01f  1
#
# Number of Iterations....: 8
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -7.9921636181417843e-08   -7.9921636181417843e-08
# Dual infeasibility......:   1.3652193524976708e-12    1.3652193524976708e-12
# Constraint violation....:   3.0473358611081732e-15    3.0473358611081732e-15
# Complementarity.........:   6.3496485871767335e-11    6.3496485871767335e-11
# Overall NLP error.......:   6.3496485871767335e-11    6.3496485871767335e-11
#
#
# Number of objective function evaluations             = 9
# Number of objective gradient evaluations             = 9
# Number of equality constraint evaluations            = 9
# Number of inequality constraint evaluations          = 9
# Number of equality constraint Jacobian evaluations   = 9
# Number of inequality constraint Jacobian evaluations = 9
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.015
# Total CPU secs in NLP function evaluations           =      0.008
#
# EXIT: Optimal Solution Found.
# This is Ipopt version 3.13.4, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      161
# Number of nonzeros in inequality constraint Jacobian.:      368
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Total number of variables............................:       23
#                      variables with only lower bounds:       16
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        7
# Total number of inequality constraints...............:       16
#         inequality constraints with only lower bounds:       16
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  8.0000000e+00 4.90e+00 6.67e-01   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.3103845e+00 9.80e-03 3.39e-01  -6.0 3.55e-01    -  1.00e+00 1.00e+00h  1
#    2  1.0631970e-01 3.37e-03 1.28e-01  -2.7 9.94e-01    -  9.86e-01 6.57e-01f  1
#    3  3.8055378e-03 7.28e-05 6.41e-02  -4.2 1.51e-02    -  9.99e-01 9.79e-01h  1
#    4  2.4283766e-04 5.77e-06 7.59e-03  -6.0 6.76e-04    -  1.00e+00 9.21e-01h  1
#    5  2.5052665e-06 1.06e-08 3.05e-05  -7.0 3.55e-05    -  1.00e+00 9.98e-01h  1
#    6 -5.0969996e-08 3.67e-10 3.18e-07 -11.0 3.54e-07    -  1.00e+00 9.65e-01h  1
#    7 -7.6876139e-08 1.47e-10 7.62e-09 -10.1 9.66e-09    -  1.00e+00 6.00e-01h  1
#    8 -7.9820510e-08 3.70e-11 1.75e-09 -11.0 2.22e-09    -  1.00e+00 7.48e-01h  1
#    9 -7.9919824e-08 9.27e-16 4.06e-10 -11.0 2.42e-09    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 9
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -7.9919824478227986e-08   -7.9919824478227986e-08
# Dual infeasibility......:   4.0596586379018640e-10    4.0596586379018640e-10
# Constraint violation....:   9.2709060060010437e-16    9.2709060060010437e-16
# Complementarity.........:   1.2733897079590895e-11    1.2733897079590895e-11
# Overall NLP error.......:   4.0596586379018640e-10    4.0596586379018640e-10
#
#
# Number of objective function evaluations             = 10
# Number of objective gradient evaluations             = 10
# Number of equality constraint evaluations            = 10
# Number of inequality constraint evaluations          = 10
# Number of equality constraint Jacobian evaluations   = 10
# Number of inequality constraint Jacobian evaluations = 10
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.015
# Total CPU secs in NLP function evaluations           =      0.009
#
# EXIT: Optimal Solution Found.
# This is Ipopt version 3.13.4, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      161
# Number of nonzeros in inequality constraint Jacobian.:      368
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Total number of variables............................:       23
#                      variables with only lower bounds:       16
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        7
# Total number of inequality constraints...............:       16
#         inequality constraints with only lower bounds:       16
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  8.0000000e+00 5.39e+00 6.88e-01   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.3150563e+00 9.80e-03 3.38e-01  -6.0 3.84e-01    -  1.00e+00 1.00e+00h  1
#    2  1.1986406e-01 3.35e-03 1.92e-01  -2.5 9.90e-01    -  9.87e-01 6.59e-01f  1
#    3  8.5718630e-03 1.45e-04 1.11e-02  -4.2 1.63e-02    -  9.99e-01 9.58e-01h  1
#    4  1.9665648e-04 2.71e-06 2.20e-03  -5.6 2.49e-03    -  1.00e+00 9.81e-01h  1
#    5  1.4444316e-06 4.85e-09 1.97e-05  -7.3 2.69e-05    -  1.00e+00 9.98e-01h  1
#    6 -5.5135842e-08 2.42e-10 1.99e-07 -11.0 2.14e-07    -  1.00e+00 9.50e-01h  1
#    7 -7.7291470e-08 1.04e-10 1.76e-11 -11.0 6.94e-09    -  1.00e+00 5.69e-01h  1
#    8 -7.9815554e-08 2.76e-11 5.50e-12 -11.0 1.44e-09    -  1.00e+00 7.35e-01h  1
#
# Number of Iterations....: 8
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -7.9815554431385451e-08   -7.9815554431385451e-08
# Dual infeasibility......:   5.5015020317128460e-12    5.5015020317128460e-12
# Constraint violation....:   2.7598368035341991e-11    2.7598368035341991e-11
# Complementarity.........:   3.2703147996747648e-10    3.2703147996747648e-10
# Overall NLP error.......:   3.2703147996747648e-10    3.2703147996747648e-10
#
#
# Number of objective function evaluations             = 9
# Number of objective gradient evaluations             = 9
# Number of equality constraint evaluations            = 9
# Number of inequality constraint evaluations          = 9
# Number of equality constraint Jacobian evaluations   = 9
# Number of inequality constraint Jacobian evaluations = 9
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.016
# Total CPU secs in NLP function evaluations           =      0.008
#
# EXIT: Optimal Solution Found.
# This is Ipopt version 3.13.4, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      161
# Number of nonzeros in inequality constraint Jacobian.:      368
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Total number of variables............................:       23
#                      variables with only lower bounds:       16
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        7
# Total number of inequality constraints...............:       16
#         inequality constraints with only lower bounds:       16
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  8.0000000e+00 5.88e+00 6.74e-01   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.3191102e+00 9.80e-03 3.37e-01  -6.1 4.09e-01    -  1.00e+00 1.00e+00h  1
#    2  1.3923567e+00 9.65e-05 4.90e-01  -2.4 5.00e-01    -  9.75e-01 1.00e+00f  1
#    3  2.8467584e-02 4.77e-05 2.35e-01  -3.7 3.40e-01    -  1.00e+00 5.05e-01f  1
#    4  6.3230440e-04 7.92e-07 5.38e-03  -5.1 9.28e-03    -  1.00e+00 9.83e-01f  1
#    5  4.6761455e-06 7.67e-10 1.84e-07  -6.8 9.10e-05    -  1.00e+00 9.99e-01h  1
#    6 -4.7720435e-08 1.20e-11 5.21e-10 -11.0 1.26e-06    -  1.00e+00 9.84e-01h  1
#    7 -7.4986212e-08 4.01e-12 5.81e-11  -9.6 1.81e-08    -  1.00e+00 6.67e-01h  1
#    8 -7.9607371e-08 1.15e-12 1.50e-11 -11.0 6.64e-09    -  1.00e+00 7.13e-01f  1
#
# Number of Iterations....: 8
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -7.9607370591061230e-08   -7.9607370591061230e-08
# Dual infeasibility......:   1.4954690263913051e-11    1.4954690263913051e-11
# Constraint violation....:   1.1507884574769810e-12    1.1507884574769810e-12
# Complementarity.........:   4.1071368220573276e-10    4.1071368220573276e-10
# Overall NLP error.......:   4.1071368220573276e-10    4.1071368220573276e-10
#
#
# Number of objective function evaluations             = 9
# Number of objective gradient evaluations             = 9
# Number of equality constraint evaluations            = 9
# Number of inequality constraint evaluations          = 9
# Number of equality constraint Jacobian evaluations   = 9
# Number of inequality constraint Jacobian evaluations = 9
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.019
# Total CPU secs in NLP function evaluations           =      0.007
#
# EXIT: Optimal Solution Found.
# This is Ipopt version 3.13.4, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      161
# Number of nonzeros in inequality constraint Jacobian.:      368
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Total number of variables............................:       23
#                      variables with only lower bounds:       16
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        7
# Total number of inequality constraints...............:       16
#         inequality constraints with only lower bounds:       16
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  8.0000000e+00 6.37e+00 8.69e-01   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.6842069e+00 8.61e-01 3.10e-01  -6.1 4.29e-01    -  1.00e+00 8.65e-01h  1
#    2  5.3190038e+00 7.84e-01 1.18e+01  -2.5 5.15e-01    -  1.00e+00 8.96e-02f  1
#    3  3.3899387e+00 2.26e-01 8.18e+02  -1.1 6.25e+00    -  3.67e-02 7.12e-01f  1
#    4  2.9427837e+00 1.32e-01 4.21e+02  -1.3 4.52e-01    -  1.00e+00 4.13e-01f  1
#    5  2.5273296e+00 9.97e-05 1.58e+00  -1.5 8.48e-01    -  1.00e+00 1.00e+00h  1
#    6  1.6988748e+00 1.19e-05 1.27e+01  -2.5 5.26e-01    -  9.99e-01 8.82e-01f  1
#    7  1.3616000e+00 5.12e-06 1.11e+01  -4.0 4.88e-01    -  1.00e+00 5.72e-01f  1
#    8  5.2730789e-01 6.23e-05 2.87e+01  -1.4 1.10e+03    -  1.13e-01 1.46e-03f  1
#    9  1.9988030e-01 1.23e-03 1.48e+02  -2.4 1.21e+01    -  7.34e-01 6.16e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.6849317e-02 1.25e-05 4.20e+01  -3.3 2.89e-01    -  1.00e+00 7.54e-01f  1
#   11  2.9868413e-04 1.30e-07 4.33e-01  -5.3 1.29e-02    -  1.00e+00 9.90e-01h  1
#   12  5.3180971e-06 1.48e-09 2.06e-07  -7.1 7.46e-04    -  1.00e+00 9.89e-01h  1
#   13 -1.2921976e-09 1.89e-11 2.65e-09  -8.6 4.98e-06    -  1.00e+00 9.87e-01h  1
#   14 -6.0612588e-08 3.73e-12 1.11e-10  -8.9 1.40e-07    -  1.00e+00 8.02e-01h  1
#   15 -7.7354168e-08 1.36e-12 4.90e-11 -11.0 1.35e-08    -  1.00e+00 6.35e-01h  1
#
# Number of Iterations....: 15
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -7.7354167792279258e-08   -7.7354167792279258e-08
# Dual infeasibility......:   4.8997361723479571e-11    4.8997361723479571e-11
# Constraint violation....:   1.3600232051658168e-12    1.3600232051658168e-12
# Complementarity.........:   8.2115842985778565e-10    8.2115842985778565e-10
# Overall NLP error.......:   8.2115842985778565e-10    8.2115842985778565e-10
#
#
# Number of objective function evaluations             = 16
# Number of objective gradient evaluations             = 16
# Number of equality constraint evaluations            = 16
# Number of inequality constraint evaluations          = 16
# Number of equality constraint Jacobian evaluations   = 16
# Number of inequality constraint Jacobian evaluations = 16
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.031
# Total CPU secs in NLP function evaluations           =      0.013
#
# EXIT: Optimal Solution Found.
# This is Ipopt version 3.13.4, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      161
# Number of nonzeros in inequality constraint Jacobian.:      368
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Total number of variables............................:       23
#                      variables with only lower bounds:       16
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        7
# Total number of inequality constraints...............:       16
#         inequality constraints with only lower bounds:       16
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  8.0000000e+00 6.43e+00 1.02e+00   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  7.9023958e+00 6.20e+00 2.27e+01  -6.2 4.32e-01    -  9.06e-01 3.65e-02h  1
#    2  1.9326088e+01 4.33e+00 1.04e+04   0.5 1.19e+02    -  7.09e-04 3.01e-01f  1
#    3  1.5625131e+01 3.00e+00 7.18e+03  -0.2 2.08e+01    -  4.91e-01 3.08e-01f  1
#    4  1.5392502e+01 2.90e+00 6.98e+03  -6.2 2.23e+01    -  3.08e-01 3.16e-02h  1
#    5  5.0017651e+01 4.14e-01 8.00e+01   0.3 2.88e+01    -  9.47e-01 1.00e+00f  1
#    6  3.4717702e+01 1.22e-02 5.18e+01   0.1 8.13e+00    -  9.79e-01 1.00e+00f  1
#    7  9.9405391e+00 5.12e-03 8.03e+01  -0.9 6.18e+00    -  1.00e+00 8.42e-01f  1
#    8  3.3565987e+00 2.28e-02 9.19e+01  -1.8 3.36e+00    -  1.00e+00 9.67e-01f  1
#    9  2.4544487e-01 6.64e-01 5.53e+01  -2.7 2.51e+01    -  1.00e+00 5.36e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  3.4629227e-01 1.06e-01 4.04e+00  -1.8 5.91e+00    -  1.00e+00 1.00e+00h  1
#   11  4.0913881e-02 1.01e-03 6.38e-01  -3.1 1.49e+00    -  1.00e+00 9.30e-01h  1
#   12  1.6118822e-03 6.78e-06 1.36e-02  -4.3 1.51e-02    -  1.00e+00 9.90e-01h  1
#   13  4.6830684e-05 1.28e-06 2.46e-03  -6.1 4.26e-04    -  1.00e+00 9.82e-01h  1
#   14  2.5503479e-06 1.17e-09 2.48e-08  -7.9 4.21e-05    -  1.00e+00 9.41e-01h  1
#   15  6.8567662e-08 6.53e-12 2.62e-09  -8.0 2.87e-06    -  1.00e+00 9.94e-01h  1
#   16 -6.4762959e-08 1.68e-12 1.78e-10 -11.0 8.50e-08    -  1.00e+00 7.43e-01h  1
#   17 -7.7575828e-08 7.53e-13 3.52e-10 -11.0 8.97e-08    -  1.00e+00 5.52e-01h  1
#   18 -7.9722851e-08 2.73e-13 1.32e-10 -11.0 8.85e-08    -  1.00e+00 6.37e-01h  1
#
# Number of Iterations....: 18
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -7.9722851011847815e-08   -7.9722851011847815e-08
# Dual infeasibility......:   1.3220169403638238e-10    1.3220169403638238e-10
# Constraint violation....:   2.7289281945286348e-13    2.7289281945286348e-13
# Complementarity.........:   2.6802400806176507e-10    2.6802400806176507e-10
# Overall NLP error.......:   2.6802400806176507e-10    2.6802400806176507e-10
#
#
# Number of objective function evaluations             = 19
# Number of objective gradient evaluations             = 19
# Number of equality constraint evaluations            = 19
# Number of inequality constraint evaluations          = 19
# Number of equality constraint Jacobian evaluations   = 19
# Number of inequality constraint Jacobian evaluations = 19
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.049
# Total CPU secs in NLP function evaluations           =      0.015
#
# EXIT: Optimal Solution Found.
# This is Ipopt version 3.13.4, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      161
# Number of nonzeros in inequality constraint Jacobian.:      368
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Total number of variables............................:       23
#                      variables with only lower bounds:       16
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        7
# Total number of inequality constraints...............:       16
#         inequality constraints with only lower bounds:       16
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  8.0000000e+00 5.03e+00 1.02e+00   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  7.8882562e+00 4.82e+00 1.94e+01  -6.2 3.34e-01    -  9.00e-01 4.19e-02h  1
#    2  1.7388798e+01 3.10e+00 9.20e+03   0.4 8.13e+01    -  8.17e-04 3.55e-01f  1
#    3  1.3923126e+01 1.91e+00 5.68e+03  -0.3 1.28e+01    -  7.95e-01 3.83e-01f  1
#    4  1.7935726e+01 1.85e+00 2.36e+03  -0.2 3.42e+01    -  4.51e-01 5.81e-01h  1
#    5  1.3837260e+01 1.66e+00 2.09e+03  -2.1 2.01e+01    -  8.48e-01 1.16e-01f  1
#    6  4.7165190e+00 1.23e-01 6.94e+01  -1.2 4.62e+00    -  1.00e+00 1.00e+00f  1
#    7  1.3592535e+00 1.96e-01 4.33e+01  -2.1 7.28e+00    -  1.00e+00 6.34e-01f  1
#    8  8.3600175e-01 2.86e-02 3.68e+01  -1.6 2.82e+00    -  1.00e+00 7.29e-01h  1
#    9  3.0472121e-01 3.68e-02 2.28e+01  -2.6 8.43e+00    -  1.00e+00 3.58e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  8.9244305e-02 5.44e-03 4.08e+00  -2.7 4.50e-01    -  1.00e+00 8.30e-01h  1
#   11  1.6060434e-03 4.27e-07 7.78e-02  -4.5 5.41e-02    -  1.00e+00 9.89e-01h  1
#   12  2.3439754e-05 3.45e-09 6.87e-04  -6.3 6.03e-04    -  1.00e+00 9.92e-01h  1
#   13  2.1123644e-06 3.51e-10 1.16e-08  -8.1 1.31e-05    -  1.00e+00 8.98e-01h  1
#   14 -5.6318899e-08 2.92e-12 2.66e-09  -8.7 1.40e-06    -  9.91e-01 9.92e-01h  1
#   15 -6.2069797e-08 2.39e-12 1.08e-05 -11.0 6.64e-06    -  1.00e+00 1.84e-01h  1
#   16 -7.7652404e-08 5.43e-13 2.77e-09 -11.0 7.66e-07    -  1.00e+00 7.72e-01f  1
#   17 -7.9826207e-08 7.48e-14 6.25e-11 -11.0 7.02e-07    -  1.00e+00 8.67e-01h  1
#
# Number of Iterations....: 17
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -7.9826206987393793e-08   -7.9826206987393793e-08
# Dual infeasibility......:   6.2469120154506896e-11    6.2469120154506896e-11
# Constraint violation....:   7.4829031859735551e-14    7.4829031859735551e-14
# Complementarity.........:   9.7334826698689422e-11    9.7334826698689422e-11
# Overall NLP error.......:   9.7334826698689422e-11    9.7334826698689422e-11
#
#
# Number of objective function evaluations             = 18
# Number of objective gradient evaluations             = 18
# Number of equality constraint evaluations            = 18
# Number of inequality constraint evaluations          = 18
# Number of equality constraint Jacobian evaluations   = 18
# Number of inequality constraint Jacobian evaluations = 18
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.046
# Total CPU secs in NLP function evaluations           =      0.014
#
# EXIT: Optimal Solution Found.
# This is Ipopt version 3.13.4, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      161
# Number of nonzeros in inequality constraint Jacobian.:      368
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Total number of variables............................:       23
#                      variables with only lower bounds:       16
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        7
# Total number of inequality constraints...............:       16
#         inequality constraints with only lower bounds:       16
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  8.0000000e+00 2.56e+00 1.02e+00   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  7.5418025e+00 6.80e-01 8.24e+00  -0.5 3.86e-01    -  1.00e+00 7.15e-01f  1
#    2  6.4064317e+00 1.37e-02 1.83e+02  -0.5 4.37e-01    -  1.39e-01 1.00e+00f  1
#    3  4.3728580e+00 1.67e-05 1.09e+00  -0.7 6.21e-01    -  1.00e+00 1.00e+00f  1
#    4  1.7654798e+00 2.17e-04 5.16e+00  -1.4 1.37e+00    -  1.00e+00 6.87e-01f  1
#    5  1.1020234e-01 1.07e-05 8.14e-01  -2.3 6.40e-01    -  1.00e+00 1.00e+00f  1
#    6  3.0484065e-03 3.19e-03 1.38e-01  -4.2 8.43e-01    -  1.00e+00 9.83e-01f  1
#    7  4.9922939e-04 5.08e-04 4.79e-02  -4.6 3.59e-01    -  1.00e+00 1.00e+00h  1
#    8  7.2248098e-06 9.99e-06 8.69e-03  -6.5 8.64e-02    -  1.00e+00 1.00e+00h  1
#    9  5.3931246e-06 2.02e-09 3.22e-07  -6.6 1.92e-03    -  1.00e+00 9.93e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10 -5.0430819e-08 2.32e-11 2.02e-08 -11.0 1.67e-05    -  1.00e+00 9.89e-01h  1
#   11 -6.9204636e-08 4.54e-12 2.34e-10  -9.2 1.25e-07    -  1.00e+00 8.04e-01h  1
#   12 -7.7490085e-08 1.66e-12 6.25e-10 -11.0 2.90e-07    -  1.00e+00 6.34e-01h  1
#
# Number of Iterations....: 12
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -7.7490084526262286e-08   -7.7490084526262286e-08
# Dual infeasibility......:   6.2503551921840039e-10    6.2503551921840039e-10
# Constraint violation....:   1.6628843500888476e-12    1.6628843500888476e-12
# Complementarity.........:   5.7398342215229464e-10    5.7398342215229464e-10
# Overall NLP error.......:   6.2503551921840039e-10    6.2503551921840039e-10
#
#
# Number of objective function evaluations             = 13
# Number of objective gradient evaluations             = 13
# Number of equality constraint evaluations            = 13
# Number of inequality constraint evaluations          = 13
# Number of equality constraint Jacobian evaluations   = 13
# Number of inequality constraint Jacobian evaluations = 13
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.031
# Total CPU secs in NLP function evaluations           =      0.010
#
# EXIT: Optimal Solution Found.
# This is Ipopt version 3.13.4, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      161
# Number of nonzeros in inequality constraint Jacobian.:      368
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Total number of variables............................:       23
#                      variables with only lower bounds:       16
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        7
# Total number of inequality constraints...............:       16
#         inequality constraints with only lower bounds:       16
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# ...
#   18 -7.8415204e-08 7.87e-14 4.70e-10 -11.0 6.79e-08    -  1.00e+00 6.44e-01f  1
#
# Number of Iterations....: 18
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -7.8415204250805268e-08   -7.8415204250805268e-08
# Dual infeasibility......:   4.7028855809649883e-10    4.7028855809649883e-10
# Constraint violation....:   7.8714812445923599e-14    7.8714812445923599e-14
# Complementarity.........:   4.1258164958017156e-10    4.1258164958017156e-10
# Overall NLP error.......:   4.7028855809649883e-10    4.7028855809649883e-10
#
#
# Number of objective function evaluations             = 19
# Number of objective gradient evaluations             = 19
# Number of equality constraint evaluations            = 19
# Number of inequality constraint evaluations          = 19
# Number of equality constraint Jacobian evaluations   = 19
# Number of inequality constraint Jacobian evaluations = 19
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.042
# Total CPU secs in NLP function evaluations           =      0.061
#
# EXIT: Optimal Solution Found.
# This is Ipopt version 3.13.4, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      161
# Number of nonzeros in inequality constraint Jacobian.:      368
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Total number of variables............................:       23
#                      variables with only lower bounds:       16
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        7
# Total number of inequality constraints...............:       16
#         inequality constraints with only lower bounds:       16
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  8.0000000e+00 2.03e+00 1.02e+00   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  7.8146800e+00 1.87e+00 1.45e+01  -1.3 3.37e-01    -  9.49e-01 8.14e-02h  1
#    2  1.7850882e+01 8.46e-01 6.33e+03   0.2 3.92e+01    -  1.78e-03 6.75e-01f  1
#    3  1.1869187e+01 1.02e-02 1.76e+01  -0.3 7.43e+00    -  1.00e+00 1.00e+00f  1
#    4  2.7714942e+00 1.98e-03 2.71e+00  -1.3 3.36e+00    -  1.00e+00 8.47e-01f  1
#    5  1.8428366e-01 9.74e-02 4.22e+00  -2.3 4.70e+00    -  1.00e+00 9.49e-01f  1
#    6  7.5680708e-02 2.16e-02 6.23e-01  -2.5 2.27e+00    -  1.00e+00 9.79e-01h  1
#    7  3.0314139e-03 1.39e-03 7.09e-02  -3.9 6.65e-01    -  1.00e+00 9.92e-01h  1
#    8  9.6340881e-05 1.29e-05 2.17e-03  -5.8 6.01e-02    -  1.00e+00 9.78e-01h  1
#    9  8.6821721e-07 2.98e-09 1.46e-07  -7.4 5.91e-04    -  1.00e+00 9.98e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  9.7013694e-08 3.83e-15 1.33e-09  -8.0 2.58e-06    -  1.00e+00 1.00e+00h  1
#   11 -6.0991358e-08 1.22e-15 8.39e-10 -11.0 5.72e-07    -  1.00e+00 7.69e-01h  1
#   12 -7.4745821e-08 7.77e-16 3.35e-09  -9.6 6.04e-07    -  1.00e+00 6.39e-01f  1
#   13 -7.8844681e-08 2.28e-15 9.58e-10 -11.0 5.49e-08    -  1.00e+00 6.17e-01f  1
#
# Number of Iterations....: 13
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -7.8844681499865744e-08   -7.8844681499865744e-08
# Dual infeasibility......:   9.5846700021162690e-10    9.5846700021162690e-10
# Constraint violation....:   2.2759572004815709e-15    2.2759572004815709e-15
# Complementarity.........:   4.4631729414057337e-10    4.4631729414057337e-10
# Overall NLP error.......:   9.5846700021162690e-10    9.5846700021162690e-10
#
#
# Number of objective function evaluations             = 14
# Number of objective gradient evaluations             = 14
# Number of equality constraint evaluations            = 14
# Number of inequality constraint evaluations          = 14
# Number of equality constraint Jacobian evaluations   = 14
# Number of inequality constraint Jacobian evaluations = 14
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.033
# Total CPU secs in NLP function evaluations           =      0.009
#
# EXIT: Optimal Solution Found.
# This is Ipopt version 3.13.4, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      161
# Number of nonzeros in inequality constraint Jacobian.:      368
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Total number of variables............................:       23
#                      variables with only lower bounds:       16
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        7
# Total number of inequality constraints...............:       16
#         inequality constraints with only lower bounds:       16
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  8.0000000e+00 2.33e+00 1.02e+00   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  7.3068758e+00 1.61e+00 5.63e+00  -1.2 3.39e-01    -  9.99e-01 3.08e-01f  1
#    2  4.0758448e+00 5.59e-03 3.66e+02  -1.0 4.02e+00    -  1.57e-01 1.00e+00f  1
#    3  1.7378128e+00 5.65e-06 3.15e-01  -1.3 3.58e-01    -  1.00e+00 1.00e+00f  1
#    4  5.6790910e-01 1.37e-06 2.03e+00  -2.3 2.71e-01    -  1.00e+00 7.73e-01f  1
#    5  2.6846189e-01 9.08e-06 1.10e+01  -2.6 3.03e+00    -  1.00e+00 1.83e-01f  1
#    6  8.7208255e-02 2.09e-03 2.48e+00  -2.7 1.29e+00    -  1.00e+00 7.93e-01f  1
#    7  3.7050066e-03 8.99e-05 2.06e-01  -3.9 2.28e-01    -  1.00e+00 9.84e-01h  1
#    8  7.6879088e-05 7.79e-07 6.61e-03  -5.7 2.13e-02    -  1.00e+00 9.93e-01h  1
#    9  1.0268777e-06 6.11e-11 1.00e-07  -7.4 6.41e-04    -  1.00e+00 9.97e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  8.3266130e-08 9.86e-12 5.69e-09  -8.8 4.07e-06    -  1.00e+00 8.39e-01h  1
#   11 -6.0645844e-08 2.32e-12 1.16e-09 -11.0 8.36e-07    -  1.00e+00 7.64e-01h  1
#   12 -7.5477181e-08 8.71e-13 4.02e-10 -10.0 1.88e-07    -  1.00e+00 6.26e-01f  1
#   13 -7.8436945e-08 3.61e-13 1.62e-10 -10.5 7.69e-08    -  1.00e+00 5.82e-01f  1
#
# Number of Iterations....: 13
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -7.8436944741130256e-08   -7.8436944741130256e-08
# Dual infeasibility......:   1.6208782926963039e-10    1.6208782926963039e-10
# Constraint violation....:   3.6140535009110408e-13    3.6140535009110408e-13
# Complementarity.........:   5.0888630573297960e-10    5.0888630573297960e-10
# Overall NLP error.......:   5.0888630573297960e-10    5.0888630573297960e-10
#
#
# Number of objective function evaluations             = 14
# Number of objective gradient evaluations             = 14
# Number of equality constraint evaluations            = 14
# Number of inequality constraint evaluations          = 14
# Number of equality constraint Jacobian evaluations   = 14
# Number of inequality constraint Jacobian evaluations = 14
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.031
# Total CPU secs in NLP function evaluations           =      0.010
#
# EXIT: Optimal Solution Found.
# This is Ipopt version 3.13.4, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      161
# Number of nonzeros in inequality constraint Jacobian.:      368
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Total number of variables............................:       23
#                      variables with only lower bounds:       16
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        7
# Total number of inequality constraints...............:       16
#         inequality constraints with only lower bounds:       16
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  8.0000000e+00 2.40e+00 1.02e+00   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  7.3068943e+00 1.67e+00 5.42e+00  -1.3 3.38e-01    -  9.95e-01 3.05e-01f  1
#    2  5.4999123e+00 6.72e-01 1.64e+02  -1.0 4.40e+00    -  1.84e-01 5.98e-01f  1
#    3  5.3019977e+00 6.33e-01 1.55e+02  -6.7 9.37e-01    -  3.62e-01 5.78e-02h  1
#    4  3.9898729e+00 1.28e-01 3.36e+01  -0.9 7.08e-01    -  1.00e+00 7.99e-01f  1
#    5  2.2318950e+00 1.96e-02 8.22e+00  -2.0 4.53e-01    -  1.00e+00 8.47e-01f  1
#    6  1.1931033e+00 4.15e-03 2.60e+00  -2.7 4.07e-01    -  1.00e+00 7.88e-01f  1
#    7  7.8765161e-01 1.85e-03 3.32e+00  -3.8 3.85e-01    -  1.00e+00 5.54e-01f  1
#    8  3.9471328e-01 1.82e-03 6.88e+01  -1.7 3.08e+01    -  7.59e-01 1.95e-02f  1
#    9  1.0837523e-01 8.37e-04 3.17e+01  -3.1 7.51e-01    -  8.70e-01 5.41e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  2.9558099e-03 2.70e-05 1.00e+00  -4.1 5.49e-02    -  1.00e+00 9.68e-01f  1
#   11  4.6073905e-05 2.01e-07 9.64e-03  -6.0 3.94e-03    -  1.00e+00 9.93e-01h  1
#   12  5.7605040e-07 1.86e-09 1.53e-07  -7.9 1.85e-04    -  1.00e+00 9.91e-01h  1
#   13  9.3638293e-08 3.05e-10 5.95e-09  -8.2 1.99e-06    -  1.00e+00 8.36e-01h  1
#   14 -2.8559562e-08 1.14e-10 1.72e-09  -9.2 4.66e-07    -  9.69e-01 6.25e-01f  1
#   15 -2.8766328e-08 1.14e-10 1.90e-05 -11.0 4.06e-04    -  1.00e+00 2.98e-03h  1
#   16 -7.5103711e-08 2.57e-11 7.11e-09 -10.2 2.26e-06    -  1.00e+00 7.75e-01f  1
#   17 -7.9536805e-08 7.20e-12 2.21e-09 -11.0 1.83e-07    -  1.00e+00 7.19e-01h  1
#   18 -7.9919694e-08 2.64e-13 1.57e-10 -11.0 5.80e-07    -  1.00e+00 9.63e-01f  1
#
# Number of Iterations....: 18
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -7.9919694283750074e-08   -7.9919694283750074e-08
# Dual infeasibility......:   1.5726593334888794e-10    1.5726593334888794e-10
# Constraint violation....:   2.6420228851908867e-13    2.6420228851908867e-13
# Complementarity.........:   1.7359936544893167e-11    1.7359936544893167e-11
# Overall NLP error.......:   1.5726593334888794e-10    1.5726593334888794e-10
#
#
# Number of objective function evaluations             = 19
# Number of objective gradient evaluations             = 19
# Number of equality constraint evaluations            = 19
# Number of inequality constraint evaluations          = 19
# Number of equality constraint Jacobian evaluations   = 19
# Number of inequality constraint Jacobian evaluations = 19
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.039
# Total CPU secs in NLP function evaluations           =      0.012
#
# EXIT: Optimal Solution Found.
# This is Ipopt version 3.13.4, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      161
# Number of nonzeros in inequality constraint Jacobian.:      368
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Total number of variables............................:       23
#                      variables with only lower bounds:       16
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        7
# Total number of inequality constraints...............:       16
#         inequality constraints with only lower bounds:       16
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  8.0000000e+00 2.41e+00 1.02e+00   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  7.4501907e+00 1.91e+00 2.89e+00  -6.2 3.34e-01    -  9.64e-01 2.06e-01h  1
#    2  4.0184200e+00 1.76e-02 7.24e+02  -1.1 5.90e+00    -  6.09e-02 1.00e+00f  1
#    3  1.7258628e+00 3.30e-03 1.36e+02  -2.1 4.22e-01    -  9.64e-01 8.13e-01f  1
#    4  8.8009274e-01 1.28e-03 4.42e+01  -2.5 3.45e-01    -  1.00e+00 6.14e-01f  1
#    5  4.9199326e-01 1.18e-03 9.94e+01  -2.5 8.07e+00    -  9.76e-01 7.55e-02f  1
#    6  3.5190703e-02 7.44e-05 6.24e+00  -3.3 5.33e-01    -  1.00e+00 9.37e-01f  1
#    7  1.0213993e-03 9.44e-05 6.98e-02  -4.4 1.77e-01    -  1.00e+00 9.93e-01h  1
#    8  1.7885260e-05 4.19e-07 1.60e-03  -6.2 1.01e-02    -  1.00e+00 9.96e-01h  1
#    9  1.6064403e-07 2.99e-11 4.45e-08  -8.0 1.50e-04    -  1.00e+00 9.95e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10 -2.4624832e-08 7.82e-12 3.62e-09  -9.0 1.18e-06    -  1.00e+00 7.38e-01h  1
#   11 -7.1152360e-08 2.25e-12 1.45e-10 -11.0 3.04e-08    -  1.00e+00 7.11e-01h  1
#   12 -7.9294624e-08 4.96e-13 1.96e-11 -11.0 2.33e-08    -  1.00e+00 7.79e-01h  1
#
# Number of Iterations....: 12
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -7.9294623760204981e-08   -7.9294623760204981e-08
# Dual infeasibility......:   1.9557044768485315e-11    1.9557044768485315e-11
# Constraint violation....:   4.9620724196230981e-13    4.9620724196230981e-13
# Complementarity.........:   3.1797853351603861e-10    3.1797853351603861e-10
# Overall NLP error.......:   3.1797853351603861e-10    3.1797853351603861e-10
#
#
# Number of objective function evaluations             = 13
# Number of objective gradient evaluations             = 13
# Number of equality constraint evaluations            = 13
# Number of inequality constraint evaluations          = 13
# Number of equality constraint Jacobian evaluations   = 13
# Number of inequality constraint Jacobian evaluations = 13
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.027
# Total CPU secs in NLP function evaluations           =      0.009
#
# EXIT: Optimal Solution Found.
# This is Ipopt version 3.13.4, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      161
# Number of nonzeros in inequality constraint Jacobian.:      368
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Total number of variables............................:       23
#                      variables with only lower bounds:       16
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        7
# Total number of inequality constraints...............:       16
#         inequality constraints with only lower bounds:       16
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  8.0000000e+00 2.35e+00 1.02e+00   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  7.2608474e+00 1.66e+00 3.18e+00  -1.6 3.32e-01    -  9.80e-01 2.95e-01h  1
#    2  3.5496770e+00 1.25e-02 4.16e+02  -1.3 3.49e+00    -  1.09e-01 9.95e-01f  1
#    3  1.2196488e+00 3.17e-04 1.08e+01  -1.6 3.49e-01    -  1.00e+00 9.75e-01f  1
#    4  4.0871729e-01 6.98e-05 5.63e-01  -2.9 2.67e-01    -  1.00e+00 7.80e-01f  1
#
# Nu

# %%
#Verify that positions look reasonable and height remains above the ground
plot(qhist[1,:])
plot!(qhist[2,:])
plot!(qhist[3,:])

# %%
#Plot contact forces. You should see zeros when the brick is in the air, followed by big spikes around impacts,
#followed by steady-state values that should add up to m*g
plot(λhist')

# %%
#Verify that the slacks are zero (within solver tolerances)
plot(shist')

# %%
#Visualize
#TODO: repeate/test with more random initial conditions
vis = Visualizer()
render(vis)
# Out:
# ┌ Info: MeshCat server started. You can open the visualizer by visiting the following URL in your browser:
# │ http://127.0.0.1:8705
# └ @ MeshCat /Users/kevintracy/.julia/packages/MeshCat/RLYij/src/visualizer.jl:73
# MeshCat.DisplayedVisualizer(MeshCat.CoreVisualizer(MeshCat.SceneTrees.SceneNode(nothing, nothing, Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}()), Set{Any}(), ip"127.0.0.1", 8705))

# %%
#Run visualization
delete!(vis)

# our box 
box = HyperRectangle(Vec(-0.5, -.5, -0.5), Vec(1, 1, 1))
setobject!(vis["box"],box)

# position history 
#r_hist = [ [sin(t_vec[i]/5);cos(t_vec[i]/8);sin(t_vec[i]/3)] for i = 1:length(t_vec)]
for k = 1:N
    
    # set position and attitude
    attitude = LinearMap(UnitQuaternion(qhist[4:7,k]))
    position = Translation(qhist[1:3,k])

    settransform!(vis["box"], compose(position,attitude))
    sleep(h)
end
